# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
INDEX_COL = 0
NAME_COL = "Name"
SEX_COL = "Sex"
PCLASS_COL = "Pclass"
AGE_COL = "Age"
SURVIVED_COL = "Survived"

AGE_GROUP_COL = "AgeCroup"

HEAD_ROWS_TO_SHOW = 15

# %%
df[:HEAD_ROWS_TO_SHOW]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df = pd.read_csv('train.csv', index_col=INDEX_COL)

# %%
df[:HEAD_ROWS_TO_SHOW]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.shape
# Out:
# (891, 11)

# %%
df.head
# Out:
# <bound method NDFrame.head of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# ...

# %%
df[SEX_COL].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[PCLASS_COL].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df[PCLASS_COL].value_counts().plot.pie()

# %%
df[AGE_COL].mean()
# Out:
# 29.69911764705882

# %%
df[AGE_COL].fillna(-1, inplace=True)
df[AGE_GROUP_COL] = df[AGE_COL].map(lambda age: int(age // 10)+1)
df[:HEAD_ROWS_TO_SHOW]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
df[AGE_GROUP_COL].value_counts()
# Out:
# 3    220
# 0    177
# 4    167
# 2    102
# 5     89
# 1     62
# 6     48
# 7     19
# 8      6
# 9      1
# Name: AgeCroup, dtype: int64

# %%
df[AGE_GROUP_COL].value_counts().plot.pie()

# %%
df[[AGE_GROUP_COL,SURVIVED_COL]][:HEAD_ROWS_TO_SHOW]
# Out:
#              AgeCroup  Survived
# PassengerId
# 1                   3         0
# 2                   4         1
# 3                   3         1
# 4                   4         1
# 5                   4         0
# 6                   0         0
# 7                   6         0
# 8                   1         0
# 9                   3         1
# 10                  2         1
# 11                  1         1
# 12                  6         1
# 13                  3         0
# 14                  4         0
# 15                  2         0

# %%
age_by_survived = df.groupby([AGE_GROUP_COL, SURVIVED_COL])
age_by_survived

# %%
age_by_survived.size()
# Out:
# AgeCroup  Survived
# 0         0           125
#           1            52
# 1         0            24
#           1            38
# 2         0            61
#           1            41
# 3         0           143
#           1            77
# 4         0            94
#           1            73
# 5         0            55
#           1            34
# 6         0            28
#           1            20
# 7         0            13
#           1             6
# 8         0             6
# 9         1             1
# dtype: int64

# %%
age_by_survived.fillna(0).plot(kind="barh", stacked=True)
